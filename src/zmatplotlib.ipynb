# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ptick
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
data_blue = pd.read_csv("/home/analys/rigid_link_log/rigid.csv")

# %%
data_blue.head()
# Out:
#    TimeStamp   a1   a2   a3        a4        a5        a6        a7        a8  \
# 0      29.61 -0.0 -0.0  2.0 -0.110135 -0.127655  0.009303 -0.095915 -0.141503
# 1      29.62 -0.0 -0.0  2.0 -0.110135 -0.127655  0.009303 -0.095915 -0.141503
# 2      29.63 -0.0 -0.0  2.0 -0.109023 -0.127101  0.010187 -0.095779 -0.141134
# 3      29.64 -0.0 -0.0  2.0 -0.109023 -0.127101  0.010187 -0.095779 -0.141134
# 4      29.65 -0.0 -0.0  2.0 -0.108487 -0.127257  0.010178 -0.095779 -0.141134
#
#          a9       a10       a11       a12       a13       a14       a15  \
# 0  1.009106 -0.155382 -0.119409  0.351019  0.042746  0.023292  0.050500
# 1  1.009106 -0.154856 -0.119142  0.351622  0.044378  0.021666  0.050168
# 2  1.010001 -0.154495 -0.118975  0.352022  0.045435  0.020576  0.049974
# 3  1.010001 -0.153936 -0.118743  0.352720  0.047184  0.018673  0.066446
# 4  1.010001 -0.153550 -0.118603  0.353458  0.048629  0.017076  0.102605
#
#         a16       a17       a18  Thrust
# 0  0.044482  0.013625 -0.028780     0.0
# 1  0.044482  0.013625 -0.028780     0.0
# 2  0.047122  0.010831 -0.029530     0.0
# 3  0.047122  0.010831 -0.029530     0.0
# 4  0.050793 -0.022706 -0.030021     0.0

# %%
plt.figure(figsize=(10,7))   # Set the size of your plot. It will determine the relative size of all the labels.
plt.figure(dpi=600)
plt.plot(data_blue['TimeStamp'],data_blue['a13'],label="gazebo_ground_truth",linewidth =0.5)
plt.plot(data_blue['TimeStamp'],data_blue['a16'],label="imu_velx",linewidth =0.5)

# plt.plot(data_blue['TimeStamp'],data_blue['setX1'],label="Y",linewidth =0.3)
# plt.plot(data_blue['TimeStamp'],data_blue['setX'],label="X",linewidth =0.3)

# plt.plot(data_blue['TimeStamp'],data_blue['odoX'],label="X",linewidth =0.3)
# plt.plot(data_blue['TimeStamp'],data_blue['odoX2'],label="Y",linewidth =0.3)
# plt.plot(data_blue['TimeStamp'],data_blue['odoX3'],label="yaw",linewidth =0.3)
 # Plot a curve.
plt.xlabel("X")
plt.ylabel("Y")
plt.title("mav trajectory generation vs  pdcs")
plt.legend()
plt.grid()
plt.savefig('/home/analys/rigid_link_log/newdnorag_a.png', dpi=600)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
